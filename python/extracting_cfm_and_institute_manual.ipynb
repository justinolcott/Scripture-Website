lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-53-moroni-1-6?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-54-moroni-7?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-55-moroni-8-9?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-56-moroni-10?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-1-keystone-of-our-religion?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-2-1-nephi-1-5?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-3-1-nephi-6-11?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-4-1-nephi-12-15?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-5-1-nephi-16-18?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-6-1-nephi-19-22?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-7-2-nephi-1-3?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-8-2-nephi-4-8?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-9-2-nephi-9-10?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-10-2-nephi-11-16?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-11-2-nephi-17-24?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-12-2-nephi-25-27?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-13-2-nephi-28-30?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-14-2-nephi-31-33?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-15-jacob-1-4?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-16-jacob-5-7?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-17-enos-words-of-mormon?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-18-mosiah-1-3?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-19-mosiah-4-8?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-20-mosiah-9-17?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-21-mosiah-18-24?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-22-mosiah-25-29?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-23-alma-1-4?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-24-alma-5-7?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-25-alma-8-12?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-26-alma-13-16?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-27-alma-17-22?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-28-alma-23-29?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-29-alma-30-31?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-30-alma-32-35?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-31-alma-36-39?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-32-alma-40-42?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-33-alma-43-51?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-34-alma-52-63?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-35-helaman-1-4?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-36-helaman-5-9?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-37-helaman-10-12?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-38-helaman-13-16?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-39-3-nephi-1-7?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-40-3-nephi-8-11?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-41-3-nephi-12-14?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-42-3-nephi-15-17?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-43-3-nephi-18-19?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-44-3-nephi-20-22?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-45-3-nephi-23-26?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-46-3-nephi-27-30?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-47-4-nephi?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-48-mormon-1-6?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-49-mormon-7-9?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-50-ether-1-5?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-51-ether-6-10?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-52-ether-11-15?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-53-moroni-1-6?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-54-moroni-7?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-55-moroni-8-9?lang=eng
# https://www.churchofjesuschrist.org//study/manual/book-of-mormon-student-manual/chapter-56-moroni-10?lang=eng

# %%
def get_page_source(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception if the response is not successful (status code >= 400)
        return response.text
    except requests.exceptions.RequestException as e:
        print(f"Error occurred while fetching {url}: {e}")
        return None

# %%
page_sources = []
for link in all_links:
    page_source = get_page_source(link)
    page_sources.append((link, page_source))

# %%
with open("manual.json", "w") as json_file:
    json.dump(page_sources, json_file)

# %%
with open("manual_page_source.json", "r") as f:
    page_sources = json.load(f)

# %%
def get_sections(page_source):
    soup = BeautifulSoup(page_source, "html.parser")
    # Find all <a> tags with href attributes that start with '/study/'
    a_tags = soup.find_all('a', href=True)

    # Replace the matching href attributes
    for a_tag in a_tags:
        if a_tag['href'].startswith('/study/'):
            a_tag['href'] = 'https://www.churchofjesuschrist.org' + a_tag['href']

    sections = []
    for header in soup.find_all("header"):
        if header.find("a", class_="scripture-ref"):
            section = header.find_parent("section")
            if section:
                a_elements = header.find_all("a", class_="scripture-ref")
                hrefs = [a.get("href") for a in a_elements]
                ref = [decode_str(a.get_text()) for a in a_elements]
                h3 = header.find("h3")
                if not h3:
                    continue
                for a in h3.find_all('a'):
                    a.extract()
                title = h3.get_text(strip=True)

                title = ''.join(h3.find_all(string=True, recursive=False))
                if title[0] == '.':
                    title = title[1:]

                ul = section.find("ul")
                content = ""
                if ul: #Institute manual has ul
                    content = ul.get_text()
                else:
                    p_elements = section.find_all('p')
                    content = '\n'.join([p.get_text() for p in p_elements])

                
                sections.append({
                    "hrefs": hrefs,
                    "ref": ref,
                    "title": decode_str(title),
                    "content": decode_str(content),
                    "html": decode_str(section.prettify())
                })
    return sections

# %%
chapters = []
for page in page_sources:
    sections = get_sections(page[1])
    chapters.append((page[0], sections))

# %%
chapters = chapters[0:56]

# %%
bom_abbreviations = {
    '1-ne' : '1 Nephi',
    '2-ne' : '2 Nephi',
    'jacob' : 'Jacob',
    'enos' : 'Enos',
    'jarom' : 'Jarom',
    'omni' : 'Omni',
    'w-of-m' : 'Words of Mormon',
    'mosiah' : 'Mosiah',
    'alma' : 'Alma',
    'hel' : 'Helaman',
    '3-ne' : '3 Nephi',
    '4-ne' : '4 Nephi',
    'morm' : 'Mormon',
    'ether' : 'Ether',
    'moro' : 'Moroni'
}

scripture_map = {
    'bom' : 'Book of Mormon',
    'ot' : 'Old Testament',
    'nt' : 'New Testament',
    'pgp' : 'Pearl of Great Price',
    'dc-testament' : 'Doctrine and Covenants'
}

file_path = 'scriptures-json/book-of-mormon.json'
bom_chapters = {}
with open(file_path, 'r') as json_file:
    book_of_mormon_data = json.load(json_file)

for book in book_of_mormon_data['books']:
    bom_chapters[book['book']] = len(book['chapters'])

# %%
def extract_scripture_info(link):
    # Remove the '?lang=eng' part from the link if it exists
    link = link.split('?')[0]

    # Split the link by '/'
    link_parts = link.split('/')

    # Extract the scripture, book, and the third element containing chapter and verses
    work = link_parts[5]
    book = link_parts[6]
    if book not in bom_abbreviations.keys():
        return None, None, None, None

    third_element = link_parts[7]
    part = third_element.split('.')
    chapter = part[0]
    if (len(part) < 2):
        return work, book, chapter, range(1, bom_chapters[bom_abbreviations[book]])
    verses = part[1]
    verses = verses.split(',')

    individual_verses = []
    for verse_range in verses:
        # Check if the verse range is in the form of '1-2'
        if '-' in verse_range:
            verse_range = verse_range.split('-')
            start_verse = verse_range[0]
            end_verse = verse_range[1]
            while int(start_verse)!= 0 or int(end_verse)!= 0:
                individual_verses.append(start_verse)
                start_verse = int(start_verse) + 1
                if int(start_verse) > int(end_verse):
                    break
        else:
            individual_verses.append(verse_range)

    return work, book, chapter, individual_verses

# %%
bom_manual_ref_map = {}
for chapter in chapters:
    for section in chapter[1]:
        for href in section['hrefs']:
            work, book, chapter_num, verses = extract_scripture_info(href)
            if (work == None):
                continue
            current_level = bom_manual_ref_map
            for level in (work, book, chapter_num):
                current_level = current_level.setdefault(level, {})
            for verse in verses:
                if verse not in current_level:
                    current_level[verse] = []
                current_level[verse].append({
                    'scripture': section['ref'],
                    'header': section['title'],
                    'content': section['content'],
                    'html': section['html']                  
                })

# %%
with open("svelte-app/src/jsons/bom_manual_map.json", 'w') as f:
    json.dump(bom_manual_ref_map, f)

# %% [markdown]
# # Come Follow Me for the Book of Mormon

# %%
cfm_link ='https://www.churchofjesuschrist.org/study/manual/come-follow-me-for-individuals-and-families-book-of-mormon-2020?lang=eng'
# UNCOMMENT THIS TO GET ALL LINKS
# cfm_links = get_all_links(link)
cfm_links = []
filtered_links = []
for link in cfm_links:
    if re.search(r'2020/\d+', link):
        filtered_links.append(link)

prefix_string = 'https://www.churchofjesuschrist.org'
links = [prefix_string + link for link in filtered_links]
page_sources = [get_page_source(link) for link in links]

# %% [markdown]
# Or load it in...

# %%
def load_page_sources_from_json(file_path):
    with open(file_path, "r") as json_file:
        return json.load(json_file)
page_sources = load_page_sources_from_json('resources/come_follow_me_2020_page_source.json')

# %%
print(page_sources[0])
# Out:
# ['https://www.churchofjesuschrist.org/study/manual/come-follow-me-for-individuals-and-families-book-of-mormon-2020/01?lang=eng', '<!DOCTYPE html>\n<html lang="en">\n    <head>\n        <meta charset="utf-8">\n        <title data-react-helmet="true">December 30–January\xa05. Introductory Pages of the Book of Mormon: “Another Testament of Jesus Christ”</title>\n        <meta name="version" content="3.28.0">\n        <meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1">\n        <meta data-react-helmet="true" name="Search.doc-aid" content="138276781"/><meta data-react-helmet="true" name="title" content="December 30–January\xa05. Introductory Pages of the Book of Mormon: “Another Testament of Jesus Christ”"/><meta data-react-helmet="true" name="description" content="December 30–January\xa05. Introductory Pages of the Book of Mormon: “Another Testament of Jesus Christ”"/><meta data-react-helmet="true" property="og:image" content="https://assets.churchofjesuschrist.org/40/c9/40c94deb1c7a8479e95d7ba6a8bcafa0d066f607/stone_arch_doorway.jpeg"/><meta data-react-helmet="true" property="og:title" content="December 30–January\xa05. Introductory Pages of the Book of Mormon: “Another Testament of Jesus Christ”"/><meta data-react-helmet="true" property="og:type" content="website"/><meta data-react-helmet="true" property="og:url" content="https://www.churchofjesuschrist.org/study/eng/manual/come-follow-me-for-individuals-and-families-book-of-mormon-2020/01"/>\n        <link rel="preconnect" href="https://foundry.churchofjesuschrist.org">\n        <link rel="preload" as="script" href="https://www.churchofjesuschrist.org/services/platform/v4/index.js?r=2" />\n        <link data-react-helmet="true" rel="preload stylesheet" as="style" type="text/css" href="https://foundry.churchofjesuschrist.org/Foundry/v1/Ensign:Sans:300@en/css" media="screen, print"/><link data-react-helmet="true" rel="preload stylesheet" as="style" type="text/css" href="https://foundry.churchofjesuschrist.org/Foundry/v1/Ensign:Serif:400@en/css" media="screen, print"/><link data-react-helmet="true" rel="preload stylesheet" as="style" type="text/css" href="https://foundry.churchofjesuschrist.org/Foundry/v1/Ensign:Sans:400@en/css" media="screen, print"/><link data-react-helmet="true" rel="preload stylesheet" as="style" type="text/css" href="https://foundry.churchofjesuschrist.org/Foundry/v1/Ensign:Sans:600@en/css" media="screen, print"/><link data-react-helmet="true" rel="preload stylesheet" as="style" type="text/css" href="https://foundry.churchofjesuschrist.org/Foundry/v1/Ensign:Sans:700@en/css" media="screen, print"/><link data-react-helmet="true" rel="preload stylesheet" as="style" type="text/css" href="https://foundry.churchofjesuschrist.org/Foundry/v1/Ensign:Sans:Italic:400@en/css" media="screen, print"/><link data-react-helmet="true" rel="preload stylesheet" as="style" type="text/css" href="https://foundry.churchofjesuschrist.org/Foundry/v1/Ensign:Sans:Italic:700@en/css" media="screen, print"/><link data-react-helmet="true" type="text/css" rel="preload stylesheet" orig-type="text/css" href="https://ips-cdn-edge.churchofjesuschrist.org/styles/css/style_global-template-mobile_lesson_scoped.css" as="style"/><link data-react-helmet="true" rel="canonical" href="https://www.churchofjesuschrist.org/study/manual/come-follow-me-for-individuals-and-families-book-of-mormon-2020/01?lang=eng"/>\n<link data-chunk="reader" rel="preload" as="style" href="/study/static/reader.74bdf0c9567c6c5c172c.css">\n<link data-chunk="overrides" rel="preload" as="style" href="/study/static/overrides.152279eec62e85a63c7f.css">\n<link data-chunk="app" rel="preload" as="style" href="/study/static/app.382b413aa36a4a98eb80.css">\n<link data-chunk="app" rel="preload" as="script" href="/study/static/react.undefined.c9625ebc6aca14a220e1.js">\n<link data-chunk="app" rel="preload" as="script" href="/study/static/eden--app.06002f0ed6f9d8798865.js">\n<link data-chunk="app" rel="preloa ...

# %%
chapters = [(page[0], get_sections(page[1])) for page in page_sources]

# %%
print(chapters[1][1][0]['ref'][0])
# Out:
# 1�Nephi 1?6

# %%
bom_cfm_ref_map = {}
for chapter in chapters:
    for section in chapter[1]:
        for href in section['hrefs']:
            work, book, chapter, verses = extract_scripture_info(href)
            if (work == None):
                continue
            current_level = bom_cfm_ref_map
            for level in (work, book, chapter):
                current_level = current_level.setdefault(level, {})
            for verse in verses:
                if verse not in current_level:
                    current_level[verse] = []
                current_level[verse].append({
                    'scripture': section['ref'],
                    'header': section['title'],
                    'content': section['content'],  
                    'html': section['html']                 
                })

# %%
print(bom_cfm_ref_map['bofm']['1-ne']['1']['1']
# Out:
# [{'scripture': ['1\xa0Nephi 1–6'], 'header': 'The scriptures are of great worth.', 'content': '1\xa0Nephi 1–6\nThe first six chapters of the Book of Mormon contain many references to sacred books, sacred records, and the word of the Lord. As you read 1\xa0Nephi 1–6, what do you learn about why the word of God is “of great worth”? (1\xa0Nephi 5:21). What do these passages teach you about the scriptures? What do you find that inspires you to search the scriptures with greater commitment?\nSee also “Scriptures Legacy” (video, ChurchofJesusChrist.org).', 'html': '<section>\n <header>\n  <p class="scripture-title" data-aid="140517897" id="scripture_title1">\n   <a class="scripture-ref" href="https://www.churchofjesuschrist.org/study/scriptures/bofm/1-ne/1?lang=eng">\n    1\xa0Nephi 1–6\n   </a>\n  </p>\n  <h3 data-aid="140517898" id="title3">\n   The scriptures are of great worth.\n  </h3>\n </header>\n <p data-aid="140517899" id="p3">\n  The first six chapters of the Book of Mormon contain many references to sacred books, sacred records, and the word of the Lord. As you read\n  <a class="scripture-ref" href="https://www.churchofjesuschrist.org/study/scriptures/bofm/1-ne/1?lang=eng">\n   1\xa0Nephi 1–6\n  </a>\n  , what do you learn about why the word of God is “of great worth”? (\n  <a class="scripture-ref" href="https://www.churchofjesuschrist.org/study/scriptures/bofm/1-ne/5.21?lang=eng#p21">\n   1\xa0Nephi 5:21\n  </a>\n  ). What do these passages teach you about the scriptures? What do you find that inspires you to search the scriptures with greater commitment?\n </p>\n <p data-aid="140517900" id="p4">\n  See also “Scriptures Legacy” (video,\n  <span class="language" lang="eng">\n   ChurchofJesusChrist.org\n  </span>\n  ).\n </p>\n <div class="sc-bvqtyr-0 duiKkI video-vMiKm video" height="auto" title="Scriptures Legacy" width="auto">\n  <div class="sc-bvqtyr-1 inwLwu">\n   <div>\n   </div>\n   <div class="sc-bvqtyr-5 bhoNaP">\n    <div class="sc-cb9hq5-0 gMbUXa">\n     <div class="sc-cb9hq5-1 eJpFlz">\n      <svg aria-valuemax="1" aria-valuemin="0" height="50" role="progressbar" viewbox="0 0 50 50" width="50">\n       <circle class="sc-cb9hq5-2 hBHaqH" cx="25" cy="25" r="22.5" stroke-width="5px">\n       </circle>\n       <circle class="sc-cb9hq5-3 bJMUkn" cx="25" cy="25" r="22.5" stroke-width="5px" style="stroke-dasharray:141.3716694115407;stroke-dashoffset:124.40706908215581">\n       </circle>\n      </svg>\n     </div>\n    </div>\n   </div>\n  </div>\n </div>\n</section>\n'}, {'scripture': ['1\xa0Nephi 1:7–15'], 'header': 'The Book of Mormon testifies of Jesus Christ.', 'content': '1\xa0Nephi 1:7–15\nTrue to the purpose stated on its title page—to convince all that Jesus is the Christ—the Book of Mormon opens with Lehi’s remarkable vision of the Savior. What do you learn about Jesus Christ from what Lehi saw? What are some of the Savior’s “great and marvelous” works in your life? (1\xa0Nephi 1:14).', 'html': '<section>\n <header>\n  <p class="scripture-title" data-aid="140517901" id="scripture_title2">\n   <a class="scripture-ref" href="https://www.churchofjesuschrist.org/study/scriptures/bofm/1-ne/1.7-15?lang=eng#p7">\n    1\xa0Nephi 1:7–15\n   </a>\n  </p>\n  <h3 data-aid="140517902" id="title4">\n   The Book of Mormon testifies of Jesus Christ.\n  </h3>\n </header>\n <p data-aid="140517903" id="p5">\n  True to the purpose stated on its title page—to convince all that Jesus is the Christ—the Book of Mormon opens with Lehi’s remarkable vision of the Savior. What do you learn about Jesus Christ from what Lehi saw? What are some of the Savior’s “great and marvelous” works in your life? (\n  <a class="scripture-ref" href="https://www.churchofjesuschrist.org/study/scriptures/bofm/1-ne/1.14?lang=eng#p14">\n   1\xa0Nephi 1:14\n  </a>\n  ).\n </p>\n</section>\n'}, {'scripture': ['1\xa0Nephi 1–7'], 'header': '', 'content': 'Throughout 1\xa0Nephi 1–7, you could encourage family members to notice interactions between members of Le ...

# %%
with open("bom_cfm_map.json", 'w') as f:
    json.dump(bom_cfm_ref_map, f)
